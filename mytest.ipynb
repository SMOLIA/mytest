# %%
for i in 1 2 3 4 5:
    print i
# Out:
#   File "<ipython-input-1-21579e872be5>", line 1
#     for i in 1 2 3 4 5:
#                ^
# SyntaxError: invalid syntax

# %%
for i in [1,2,3,4,5,6,7]:
    print i
# Out:
# 1
# 2
# 3
# 4
# 5
